# %%
# !pip install -U spacy[cuda110,transformers,lookups]==3.0.3
# !pip install -U spacy-lookups-data==1.0.0
# !pip install cupy-cuda110==8.5.0
# !python -m spacy download en_core_web_trf
# Out:
# Requirement already satisfied: spacy[cuda110,lookups,transformers]==3.0.3 in /home/ajh1729/anaconda3/envs/ajh/lib/python3.9/site-packages (3.0.3)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.0 in /home/ajh1729/anaconda3/envs/ajh/lib/python3.9/site-packages (from spacy[cuda110,lookups,transformers]==3.0.3) (3.0.12)
# Requirement already satisfied: pydantic<1.8.0,>=1.7.1 in /home/ajh1729/anaconda3/envs/ajh/lib/python3.9/site-packages (from spacy[cuda110,lookups,transformers]==3.0.3) (1.7.4)
# Requirement already satisfied: setuptools in /home/ajh1729/anaconda3/envs/ajh/lib/python3.9/site-packages (from spacy[cuda110,lookups,transformers]==3.0.3) (65.5.0)
# Requirement already satisfied: numpy>=1.15.0 in /home/ajh1729/anaconda3/envs/ajh/lib/python3.9/site-packages (from spacy[cuda110,lookups,transformers]==3.0.3) (1.24.0)
# Requirement already satisfied: srsly<3.0.0,>=2.4.0 in /home/ajh1729/anaconda3/envs/ajh/lib/python3.9/site-packages (from spacy[cuda110,lookups,transformers]==3.0.3) (2.5.1)
# Requirement already satisfied: pathy in /home/ajh1729/anaconda3/envs/ajh/lib/python3.9/site-packages (from spacy[cuda110,lookups,transformers]==3.0.3) (0.11.0)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in /home/ajh1729/anaconda3/envs/ajh/lib/python3.9/site-packages (from spacy[cuda110,lookups,transformers]==3.0.3) (0.7.11)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /home/ajh1729/anaconda3/envs/ajh/lib/python3.9/site-packages (from spacy[cuda110,lookups,transformers]==3.0.3) (3.0.9)
# Requirement already satisfied: wasabi<1.1.0,>=0.8.1 in /home/ajh1729/anaconda3/envs/ajh/lib/python3.9/site-packages (from spacy[cuda110,lookups,transformers]==3.0.3) (0.10.1)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /home/ajh1729/anaconda3/envs/ajh/lib/python3.9/site-packages (from spacy[cuda110,lookups,transformers]==3.0.3) (2.31.0)
# Requirement already satisfied: thinc<8.1.0,>=8.0.0 in /home/ajh1729/anaconda3/envs/ajh/lib/python3.9/site-packages (from spacy[cuda110,lookups,transformers]==3.0.3) (8.0.17)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /home/ajh1729/anaconda3/envs/ajh/lib/python3.9/site-packages (from spacy[cuda110,lookups,transformers]==3.0.3) (2.0.11)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.1 in /home/ajh1729/anaconda3/envs/ajh/lib/python3.9/site-packages (from spacy[cuda110,lookups,transformers]==3.0.3) (2.0.10)
# Requirement already satisfied: packaging>=20.0 in /home/ajh1729/anaconda3/envs/ajh/lib/python3.9/site-packages (from spacy[cuda110,lookups,transformers]==3.0.3) (24.1)
# Requirement already satisfied: typer<0.4.0,>=0.3.0 in /home/ajh1729/anaconda3/envs/ajh/lib/python3.9/site-packages (from spacy[cuda110,lookups,transformers]==3.0.3) (0.3.2)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /home/ajh1729/anaconda3/envs/ajh/lib/python3.9/site-packages (from spacy[cuda110,lookups,transformers]==3.0.3) (1.0.12)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /home/ajh1729/anaconda3/envs/ajh/lib/python3.9/site-packages (from spacy[cuda110,lookups,transformers]==3.0.3) (4.66.1)
# Requirement already satisfied: jinja2 in /home/ajh1729/anaconda3/envs/ajh/lib/python3.9/site-packages (from spacy[cuda110,lookups,transformers]==3.0.3) (3.1.2)
# Requirement already satisfied: spacy-transformers<1.1.0,>=1.0.1 in /home/ajh1729/anaconda3/envs/ajh/lib/python3.9/site-packages (from spacy[cuda110,lookups,transformers]==3.0.3) (1.0.4)
# Requirement already satisfied: cupy-cuda110<9.0.0,>=5.0.0b4 in /home/ajh1729/anaconda3/envs/ajh/lib/python3.9/site-packages (from spacy[cuda110,lookups,transformers]==3.0.3) (8.5.0)
# Requirement already satisfied: spacy-lookups-data<1.1.0,>=1.0.0 in /home/ajh1729/anaconda3/envs/ajh/lib/python3.9/site-packages (from spacy[cuda110,lookups,transformers]==3.0.3) (1.0.0)
# Requirement already satisfied: fastrlock>=0.3 in /home/ajh1729/anaconda3/envs/ajh/lib/python3.9/site-packages (from cupy-cuda110<9.0.0,>=5.0.0b4->spacy[cuda110,lookups,transformers]==3.0.3) (0.8.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/ajh1729/anaconda3/envs/ajh/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy[cuda110,lookups,transformers]==3.0.3) (3.2.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/ajh1729/anaconda3/envs/ajh/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy[cuda110,lookups,transformers]==3.0.3) (2024.7.4)
# Requirement already satisfied: idna<4,>=2.5 in /home/ajh1729/anaconda3/envs/ajh/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy[cuda110,lookups,transformers]==3.0.3) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/ajh1729/anaconda3/envs/ajh/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy[cuda110,lookups,transformers]==3.0.3) (2.0.4)
# Requirement already satisfied: torch>=1.5.0 in /home/ajh1729/anaconda3/envs/ajh/lib/python3.9/site-packages (from spacy-transformers<1.1.0,>=1.0.1->spacy[cuda110,lookups,transformers]==3.0.3) (2.1.2)
# Requirement already satisfied: spacy-alignments<1.0.0,>=0.7.2 in /home/ajh1729/anaconda3/envs/ajh/lib/python3.9/site-packages (from spacy-transformers<1.1.0,>=1.0.1->spacy[cuda110,lookups,transformers]==3.0.3) (0.9.1)
# Requirement already satisfied: transformers<4.10.0,>=3.4.0 in /home/ajh1729/anaconda3/envs/ajh/lib/python3.9/site-packages (from spacy-transformers<1.1.0,>=1.0.1->spacy[cuda110,lookups,transformers]==3.0.3) (4.9.2)
# Requirement already satisfied: click<7.2.0,>=7.1.1 in /home/ajh1729/anaconda3/envs/ajh/lib/python3.9/site-packages (from typer<0.4.0,>=0.3.0->spacy[cuda110,lookups,transformers]==3.0.3) (7.1.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/ajh1729/anaconda3/envs/ajh/lib/python3.9/site-packages (from jinja2->spacy[cuda110,lookups,transformers]==3.0.3) (2.1.1)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /home/ajh1729/anaconda3/envs/ajh/lib/python3.9/site-packages (from pathy->spacy[cuda110,lookups,transformers]==3.0.3) (6.4.0)
# Requirement already satisfied: pathlib-abc==0.1.1 in /home/ajh1729/anaconda3/envs/ajh/lib/python3.9/site-packages (from pathy->spacy[cuda110,lookups,transformers]==3.0.3) (0.1.1)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /home/ajh1729/anaconda3/envs/ajh/lib/python3.9/site-packages (from torch>=1.5.0->spacy-transformers<1.1.0,>=1.0.1->spacy[cuda110,lookups,transformers]==3.0.3) (12.1.105)
# Requirement already satisfied: triton==2.1.0 in /home/ajh1729/anaconda3/envs/ajh/lib/python3.9/site-packages (from torch>=1.5.0->spacy-transformers<1.1.0,>=1.0.1->spacy[cuda110,lookups,transformers]==3.0.3) (2.1.0)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /home/ajh1729/anaconda3/envs/ajh/lib/python3.9/site-packages (from torch>=1.5.0->spacy-transformers<1.1.0,>=1.0.1->spacy[cuda110,lookups,transformers]==3.0.3) (12.1.3.1)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /home/ajh1729/anaconda3/envs/ajh/lib/python3.9/site-packages (from torch>=1.5.0->spacy-transformers<1.1.0,>=1.0.1->spacy[cuda110,lookups,transformers]==3.0.3) (8.9.2.26)
# Requirement already satisfied: typing-extensions in /home/ajh1729/anaconda3/envs/ajh/lib/python3.9/site-packages (from torch>=1.5.0->spacy-transformers<1.1.0,>=1.0.1->spacy[cuda110,lookups,transformers]==3.0.3) (4.7.1)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /home/ajh1729/anaconda3/envs/ajh/lib/python3.9/site-packages (from torch>=1.5.0->spacy-transformers<1.1.0,>=1.0.1->spacy[cuda110,lookups,transformers]==3.0.3) (12.1.105)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /home/ajh1729/anaconda3/envs/ajh/lib/python3.9/site-packages (from torch>=1.5.0->spacy-transformers<1.1.0,>=1.0.1->spacy[cuda110,lookups,transformers]==3.0.3) (11.0.2.54)
# Requirement already satisfied: nvidia-nccl-cu12==2.18.1 in /home/ajh1729/anaconda3/envs/ajh/lib/python3.9/site-packages (from torch>=1.5.0->spacy-transformers<1.1.0,>=1.0.1->spacy[cuda110,lookups,transformers]==3.0.3) (2.18.1)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /home/ajh1729/anaconda3/envs/ajh/lib/python3.9/site-packages (from torch>=1.5.0->spacy-transformers<1.1.0,>=1.0.1->spacy[cuda110,lookups,transformers]==3.0.3) (11.4.5.107)
# Requirement already satisfied: fsspec in /home/ajh1729/anaconda3/envs/ajh/lib/python3.9/site-packages (from torch>=1.5.0->spacy-transformers<1.1.0,>=1.0.1->spacy[cuda110,lookups,transformers]==3.0.3) (2024.6.0)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /home/ajh1729/anaconda3/envs/ajh/lib/python3.9/site-packages (from torch>=1.5.0->spacy-transformers<1.1.0,>=1.0.1->spacy[cuda110,lookups,transformers]==3.0.3) (12.1.105)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /home/ajh1729/anaconda3/envs/ajh/lib/python3.9/site-packages (from torch>=1.5.0->spacy-transformers<1.1.0,>=1.0.1->spacy[cuda110,lookups,transformers]==3.0.3) (12.1.105)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /home/ajh1729/anaconda3/envs/ajh/lib/python3.9/site-packages (from torch>=1.5.0->spacy-transformers<1.1.0,>=1.0.1->spacy[cuda110,lookups,transformers]==3.0.3) (12.1.0.106)
# Requirement already satisfied: filelock in /home/ajh1729/anaconda3/envs/ajh/lib/python3.9/site-packages (from torch>=1.5.0->spacy-transformers<1.1.0,>=1.0.1->spacy[cuda110,lookups,transformers]==3.0.3) (3.13.1)
# Requirement already satisfied: networkx in /home/ajh1729/anaconda3/envs/ajh/lib/python3.9/site-packages (from torch>=1.5.0->spacy-transformers<1.1.0,>=1.0.1->spacy[cuda110,lookups,transformers]==3.0.3) (3.1)
# Requirement already satisfied: sympy in /home/ajh1729/anaconda3/envs/ajh/lib/python3.9/site-packages (from torch>=1.5.0->spacy-transformers<1.1.0,>=1.0.1->spacy[cuda110,lookups,transformers]==3.0.3) (1.12)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /home/ajh1729/anaconda3/envs/ajh/lib/python3.9/site-packages (from torch>=1.5.0->spacy-transformers<1.1.0,>=1.0.1->spacy[cuda110,lookups,transformers]==3.0.3) (10.3.2.106)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /home/ajh1729/anaconda3/envs/ajh/lib/python3.9/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.5.0->spacy-transformers<1.1.0,>=1.0.1->spacy[cuda110,lookups,transformers]==3.0.3) (12.3.101)
# Requirement already satisfied: huggingface-hub==0.0.12 in /home/ajh1729/anaconda3/envs/ajh/lib/python3.9/site-packages (from transformers<4.10.0,>=3.4.0->spacy-transformers<1.1.0,>=1.0.1->spacy[cuda110,lookups,transformers]==3.0.3) (0.0.12)
# Requirement already satisfied: tokenizers<0.11,>=0.10.1 in /home/ajh1729/anaconda3/envs/ajh/lib/python3.9/site-packages (from transformers<4.10.0,>=3.4.0->spacy-transformers<1.1.0,>=1.0.1->spacy[cuda110,lookups,transformers]==3.0.3) (0.10.3)
# Requirement already satisfied: sacremoses in /home/ajh1729/anaconda3/envs/ajh/lib/python3.9/site-packages (from transformers<4.10.0,>=3.4.0->spacy-transformers<1.1.0,>=1.0.1->spacy[cuda110,lookups,transformers]==3.0.3) (0.1.1)
# Requirement already satisfied: regex!=2019.12.17 in /home/ajh1729/anaconda3/envs/ajh/lib/python3.9/site-packages (from transformers<4.10.0,>=3.4.0->spacy-transformers<1.1.0,>=1.0.1->spacy[cuda110,lookups,transformers]==3.0.3) (2024.11.6)
# Requirement already satisfied: pyyaml>=5.1 in /home/ajh1729/anaconda3/envs/ajh/lib/python3.9/site-packages (from transformers<4.10.0,>=3.4.0->spacy-transformers<1.1.0,>=1.0.1->spacy[cuda110,lookups,transformers]==3.0.3) (6.0.1)
# Requirement already satisfied: joblib in /home/ajh1729/anaconda3/envs/ajh/lib/python3.9/site-packages (from sacremoses->transformers<4.10.0,>=3.4.0->spacy-transformers<1.1.0,>=1.0.1->spacy[cuda110,lookups,transformers]==3.0.3) (1.2.0)
# Requirement already satisfied: mpmath>=0.19 in /home/ajh1729/anaconda3/envs/ajh/lib/python3.9/site-packages (from sympy->torch>=1.5.0->spacy-transformers<1.1.0,>=1.0.1->spacy[cuda110,lookups,transformers]==3.0.3) (1.3.0)
# Requirement already satisfied: spacy-lookups-data==1.0.0 in /home/ajh1729/anaconda3/envs/ajh/lib/python3.9/site-packages (1.0.0)
# Requirement already satisfied: setuptools in /home/ajh1729/anaconda3/envs/ajh/lib/python3.9/site-packages (from spacy-lookups-data==1.0.0) (65.5.0)
# Requirement already satisfied: cupy-cuda110==8.5.0 in /home/ajh1729/anaconda3/envs/ajh/lib/python3.9/site-packages (8.5.0)
# Requirement already satisfied: numpy>=1.15 in /home/ajh1729/anaconda3/envs/ajh/lib/python3.9/site-packages (from cupy-cuda110==8.5.0) (1.24.0)
# Requirement already satisfied: fastrlock>=0.3 in /home/ajh1729/anaconda3/envs/ajh/lib/python3.9/site-packages (from cupy-cuda110==8.5.0) (0.8.3)
# 2025-03-04 21:30:14.838804: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# Collecting en-core-web-trf==3.0.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_trf-3.0.0/en_core_web_trf-3.0.0-py3-none-any.whl (459.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 459.7/459.7 MB 5.0 MB/s eta 0:00:0000:0100:02
# Requirement already satisfied: spacy-transformers<1.1.0,>=1.0.0rc4 in /home/ajh1729/anaconda3/envs/ajh/lib/python3.9/site-packages (from en-core-web-trf==3.0.0) (1.0.4)
# Requirement already satisfied: spacy<3.1.0,>=3.0.0 in /home/ajh1729/anaconda3/envs/ajh/lib/python3.9/site-packages (from en-core-web-trf==3.0.0) (3.0.3)
# Requirement already satisfied: typer<0.4.0,>=0.3.0 in /home/ajh1729/anaconda3/envs/ajh/lib/python3.9/site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-trf==3.0.0) (0.3.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.0 in /home/ajh1729/anaconda3/envs/ajh/lib/python3.9/site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-trf==3.0.0) (2.5.1)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /home/ajh1729/anaconda3/envs/ajh/lib/python3.9/site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-trf==3.0.0) (1.0.12)
# Requirement already satisfied: pydantic<1.8.0,>=1.7.1 in /home/ajh1729/anaconda3/envs/ajh/lib/python3.9/site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-trf==3.0.0) (1.7.4)
# Requirement already satisfied: jinja2 in /home/ajh1729/anaconda3/envs/ajh/lib/python3.9/site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-trf==3.0.0) (3.1.2)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /home/ajh1729/anaconda3/envs/ajh/lib/python3.9/site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-trf==3.0.0) (3.0.9)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.0 in /home/ajh1729/anaconda3/envs/ajh/lib/python3.9/site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-trf==3.0.0) (3.0.12)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /home/ajh1729/anaconda3/envs/ajh/lib/python3.9/site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-trf==3.0.0) (4.66.1)
# Requirement already satisfied: packaging>=20.0 in /home/ajh1729/anaconda3/envs/ajh/lib/python3.9/site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-trf==3.0.0) (24.1)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /home/ajh1729/anaconda3/envs/ajh/lib/python3.9/site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-trf==3.0.0) (2.0.11)
# Requirement already satisfied: wasabi<1.1.0,>=0.8.1 in /home/ajh1729/anaconda3/envs/ajh/lib/python3.9/site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-trf==3.0.0) (0.10.1)
# Requirement already satisfied: pathy in /home/ajh1729/anaconda3/envs/ajh/lib/python3.9/site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-trf==3.0.0) (0.11.0)
# Requirement already satisfied: setuptools in /home/ajh1729/anaconda3/envs/ajh/lib/python3.9/site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-trf==3.0.0) (65.5.0)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /home/ajh1729/anaconda3/envs/ajh/lib/python3.9/site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-trf==3.0.0) (2.31.0)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.1 in /home/ajh1729/anaconda3/envs/ajh/lib/python3.9/site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-trf==3.0.0) (2.0.10)
# Requirement already satisfied: thinc<8.1.0,>=8.0.0 in /home/ajh1729/anaconda3/envs/ajh/lib/python3.9/site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-trf==3.0.0) (8.0.17)
# Requirement already satisfied: numpy>=1.15.0 in /home/ajh1729/anaconda3/envs/ajh/lib/python3.9/site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-trf==3.0.0) (1.24.0)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in /home/ajh1729/anaconda3/envs/ajh/lib/python3.9/site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-trf==3.0.0) (0.7.11)
# Requirement already satisfied: spacy-alignments<1.0.0,>=0.7.2 in /home/ajh1729/anaconda3/envs/ajh/lib/python3.9/site-packages (from spacy-transformers<1.1.0,>=1.0.0rc4->en-core-web-trf==3.0.0) (0.9.1)
# Requirement already satisfied: torch>=1.5.0 in /home/ajh1729/anaconda3/envs/ajh/lib/python3.9/site-packages (from spacy-transformers<1.1.0,>=1.0.0rc4->en-core-web-trf==3.0.0) (2.1.2)
# Requirement already satisfied: transformers<4.10.0,>=3.4.0 in /home/ajh1729/anaconda3/envs/ajh/lib/python3.9/site-packages (from spacy-transformers<1.1.0,>=1.0.0rc4->en-core-web-trf==3.0.0) (4.9.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/ajh1729/anaconda3/envs/ajh/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.1.0,>=3.0.0->en-core-web-trf==3.0.0) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /home/ajh1729/anaconda3/envs/ajh/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.1.0,>=3.0.0->en-core-web-trf==3.0.0) (2024.7.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/ajh1729/anaconda3/envs/ajh/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.1.0,>=3.0.0->en-core-web-trf==3.0.0) (2.0.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/ajh1729/anaconda3/envs/ajh/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.1.0,>=3.0.0->en-core-web-trf==3.0.0) (3.2.0)
# Requirement already satisfied: sympy in /home/ajh1729/anaconda3/envs/ajh/lib/python3.9/site-packages (from torch>=1.5.0->spacy-transformers<1.1.0,>=1.0.0rc4->en-core-web-trf==3.0.0) (1.12)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /home/ajh1729/anaconda3/envs/ajh/lib/python3.9/site-packages (from torch>=1.5.0->spacy-transformers<1.1.0,>=1.0.0rc4->en-core-web-trf==3.0.0) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /home/ajh1729/anaconda3/envs/ajh/lib/python3.9/site-packages (from torch>=1.5.0->spacy-transformers<1.1.0,>=1.0.0rc4->en-core-web-trf==3.0.0) (10.3.2.106)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /home/ajh1729/anaconda3/envs/ajh/lib/python3.9/site-packages (from torch>=1.5.0->spacy-transformers<1.1.0,>=1.0.0rc4->en-core-web-trf==3.0.0) (12.1.0.106)
# Requirement already satisfied: triton==2.1.0 in /home/ajh1729/anaconda3/envs/ajh/lib/python3.9/site-packages (from torch>=1.5.0->spacy-transformers<1.1.0,>=1.0.0rc4->en-core-web-trf==3.0.0) (2.1.0)
# Requirement already satisfied: filelock in /home/ajh1729/anaconda3/envs/ajh/lib/python3.9/site-packages (from torch>=1.5.0->spacy-transformers<1.1.0,>=1.0.0rc4->en-core-web-trf==3.0.0) (3.13.1)
# Requirement already satisfied: networkx in /home/ajh1729/anaconda3/envs/ajh/lib/python3.9/site-packages (from torch>=1.5.0->spacy-transformers<1.1.0,>=1.0.0rc4->en-core-web-trf==3.0.0) (3.1)
# Requirement already satisfied: fsspec in /home/ajh1729/anaconda3/envs/ajh/lib/python3.9/site-packages (from torch>=1.5.0->spacy-transformers<1.1.0,>=1.0.0rc4->en-core-web-trf==3.0.0) (2024.6.0)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /home/ajh1729/anaconda3/envs/ajh/lib/python3.9/site-packages (from torch>=1.5.0->spacy-transformers<1.1.0,>=1.0.0rc4->en-core-web-trf==3.0.0) (12.1.105)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /home/ajh1729/anaconda3/envs/ajh/lib/python3.9/site-packages (from torch>=1.5.0->spacy-transformers<1.1.0,>=1.0.0rc4->en-core-web-trf==3.0.0) (11.4.5.107)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /home/ajh1729/anaconda3/envs/ajh/lib/python3.9/site-packages (from torch>=1.5.0->spacy-transformers<1.1.0,>=1.0.0rc4->en-core-web-trf==3.0.0) (12.1.105)
# Requirement already satisfied: nvidia-nccl-cu12==2.18.1 in /home/ajh1729/anaconda3/envs/ajh/lib/python3.9/site-packages (from torch>=1.5.0->spacy-transformers<1.1.0,>=1.0.0rc4->en-core-web-trf==3.0.0) (2.18.1)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /home/ajh1729/anaconda3/envs/ajh/lib/python3.9/site-packages (from torch>=1.5.0->spacy-transformers<1.1.0,>=1.0.0rc4->en-core-web-trf==3.0.0) (12.1.3.1)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /home/ajh1729/anaconda3/envs/ajh/lib/python3.9/site-packages (from torch>=1.5.0->spacy-transformers<1.1.0,>=1.0.0rc4->en-core-web-trf==3.0.0) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /home/ajh1729/anaconda3/envs/ajh/lib/python3.9/site-packages (from torch>=1.5.0->spacy-transformers<1.1.0,>=1.0.0rc4->en-core-web-trf==3.0.0) (8.9.2.26)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /home/ajh1729/anaconda3/envs/ajh/lib/python3.9/site-packages (from torch>=1.5.0->spacy-transformers<1.1.0,>=1.0.0rc4->en-core-web-trf==3.0.0) (12.1.105)
# Requirement already satisfied: typing-extensions in /home/ajh1729/anaconda3/envs/ajh/lib/python3.9/site-packages (from torch>=1.5.0->spacy-transformers<1.1.0,>=1.0.0rc4->en-core-web-trf==3.0.0) (4.7.1)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /home/ajh1729/anaconda3/envs/ajh/lib/python3.9/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.5.0->spacy-transformers<1.1.0,>=1.0.0rc4->en-core-web-trf==3.0.0) (12.3.101)
# Requirement already satisfied: huggingface-hub==0.0.12 in /home/ajh1729/anaconda3/envs/ajh/lib/python3.9/site-packages (from transformers<4.10.0,>=3.4.0->spacy-transformers<1.1.0,>=1.0.0rc4->en-core-web-trf==3.0.0) (0.0.12)
# Requirement already satisfied: tokenizers<0.11,>=0.10.1 in /home/ajh1729/anaconda3/envs/ajh/lib/python3.9/site-packages (from transformers<4.10.0,>=3.4.0->spacy-transformers<1.1.0,>=1.0.0rc4->en-core-web-trf==3.0.0) (0.10.3)
# Requirement already satisfied: pyyaml>=5.1 in /home/ajh1729/anaconda3/envs/ajh/lib/python3.9/site-packages (from transformers<4.10.0,>=3.4.0->spacy-transformers<1.1.0,>=1.0.0rc4->en-core-web-trf==3.0.0) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /home/ajh1729/anaconda3/envs/ajh/lib/python3.9/site-packages (from transformers<4.10.0,>=3.4.0->spacy-transformers<1.1.0,>=1.0.0rc4->en-core-web-trf==3.0.0) (2024.11.6)
# Requirement already satisfied: sacremoses in /home/ajh1729/anaconda3/envs/ajh/lib/python3.9/site-packages (from transformers<4.10.0,>=3.4.0->spacy-transformers<1.1.0,>=1.0.0rc4->en-core-web-trf==3.0.0) (0.1.1)
# Requirement already satisfied: click<7.2.0,>=7.1.1 in /home/ajh1729/anaconda3/envs/ajh/lib/python3.9/site-packages (from typer<0.4.0,>=0.3.0->spacy<3.1.0,>=3.0.0->en-core-web-trf==3.0.0) (7.1.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/ajh1729/anaconda3/envs/ajh/lib/python3.9/site-packages (from jinja2->spacy<3.1.0,>=3.0.0->en-core-web-trf==3.0.0) (2.1.1)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /home/ajh1729/anaconda3/envs/ajh/lib/python3.9/site-packages (from pathy->spacy<3.1.0,>=3.0.0->en-core-web-trf==3.0.0) (6.4.0)
# Requirement already satisfied: pathlib-abc==0.1.1 in /home/ajh1729/anaconda3/envs/ajh/lib/python3.9/site-packages (from pathy->spacy<3.1.0,>=3.0.0->en-core-web-trf==3.0.0) (0.1.1)
# Requirement already satisfied: joblib in /home/ajh1729/anaconda3/envs/ajh/lib/python3.9/site-packages (from sacremoses->transformers<4.10.0,>=3.4.0->spacy-transformers<1.1.0,>=1.0.0rc4->en-core-web-trf==3.0.0) (1.2.0)
# Requirement already satisfied: mpmath>=0.19 in /home/ajh1729/anaconda3/envs/ajh/lib/python3.9/site-packages (from sympy->torch>=1.5.0->spacy-transformers<1.1.0,>=1.0.0rc4->en-core-web-trf==3.0.0) (1.3.0)
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_trf')

# %%
# Import spacy and download language model
import spacy
nlp = spacy.load('en_core_web_trf')
# Out:
# 2025-03-04 21:31:05.857855: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1

# %%
# Tokenization
sentence = nlp.tokenizer("We live in Paris.")

# Length of sentence
print("The number of tokens: ", len(sentence))

# Print individual words (i.e., tokens)
print("The tokens: ")
for words in sentence:
    print(words)
# Out:
# The number of tokens:  5
# The tokens:
# We
# live
# in
# Paris
# .

# %%
# !pip install kagglehub
# Out:
# Requirement already satisfied: kagglehub in /home/ajh1729/anaconda3/envs/ajh/lib/python3.9/site-packages (0.3.10)
# Requirement already satisfied: tqdm in /home/ajh1729/anaconda3/envs/ajh/lib/python3.9/site-packages (from kagglehub) (4.66.1)
# Requirement already satisfied: requests in /home/ajh1729/anaconda3/envs/ajh/lib/python3.9/site-packages (from kagglehub) (2.31.0)
# Requirement already satisfied: pyyaml in /home/ajh1729/anaconda3/envs/ajh/lib/python3.9/site-packages (from kagglehub) (6.0.1)
# Requirement already satisfied: packaging in /home/ajh1729/anaconda3/envs/ajh/lib/python3.9/site-packages (from kagglehub) (24.1)
# Requirement already satisfied: idna<4,>=2.5 in /home/ajh1729/anaconda3/envs/ajh/lib/python3.9/site-packages (from requests->kagglehub) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/ajh1729/anaconda3/envs/ajh/lib/python3.9/site-packages (from requests->kagglehub) (2.0.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/ajh1729/anaconda3/envs/ajh/lib/python3.9/site-packages (from requests->kagglehub) (3.2.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/ajh1729/anaconda3/envs/ajh/lib/python3.9/site-packages (from requests->kagglehub) (2024.7.4)

# %% [markdown]
# ## NLP Tasks
# 1. Tokenization (토큰화)\
#     문장을 단어, 구두점, 기호 등으로 분할\
#     토큰화 완료 후 토큰에 메타데이터(품사 태깅) 할당하여 다른 요소들과의 관계를 고려하여 각 토큰을 어떻게 처리할지 결정\
#
# 2. Part-of-Speech Tagging (품사 태깅)
#     각 토큰에 대해 명사, 대명사, 동사, 부사, … 등의 품사를 할당 \
#     메타데이터란 바로 이 품사를 말하는것. 단어들간의 관계를 파악\
#
# 3. Dependency Parsing (의존구문분석)
#     문장→ 토큰 간 관계 집합 으로 변환. 문장의 문법적 구조를 결정\
#     We live in Paris\
#     We : 대명사, live의 주어\
#     live : 동사, 현재형\
#     in Paris : 전치사구\
#     in : 전치사\
#     Paris : 전치사의 목적어, 단수 고유 명사\
#
# 4. Chunk (덩어리)
#     서로 관련된 토큰을 하나로 묶어 명사구, 동사구 등의 덩어리를 생성 (ex. New York city)\
#     토큰화 → 품사태깅 → 의존구문분석 → 청킹\
#     청킹을 통해 분석해야할 토큰 수가 줄어들어 더 빠르고 정확하게 NLP 작업 가능\
#
# 5. Lemmatizaiton (표제어 추출)
#     단어를 기본형(lemma)으로 변환\
#     horses → horse, slept → sleep, …\
#     동일한 의미의 단어의 다양한 변형을 하나로 통합 가능. 더 적은 수의 단어로 언어 이해 가능\
#
# 6. Stemming (어간 추출)
#     표제어 추출과 비슷. rule-based algorithm으로 단어를 기본형태로 변환\
#     sleeping → sleep, slept → 불규칙동사 처리 불가\
#     그러나 running → runn 같이 비정상적인 변환 발생 가능성 있음\
#     어간추출보다 표제어 추출이 더 정확하지만 품사 정보를 고려하므로 계산 비용이 든다.\
#
# 7. Named Entity Recognition (중요 개체 인식)
#     텍스트에서 사람, 조직, 장소, 날짜, 화폐 단위 등의 고유명사 식별, 태깅하는 작업\
#     Paris → 지명(location)\
#
# 8. Entity Linking (개체 연결)
#     텍스트 내 개체를 외부 DB와 연결 & 중복, 혼동될 수 있는 개체를 올바르게 식별\
#     가령 Bush 라고 했을때 아버지 부시인지 아들 부시인지 개체를 정확하게 연결해야함\
#
# 1~6 (토큰화~어간추출)은 NLP 시스템이 텍스트를 이해하기 위한 기본 단계\
# 7~8 (NER, 개체 연결)은 NLP 시스템이 정보를 검색, 활용할 수 있는 고급 기술

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("tunguz/200000-jeopardy-questions")

print("Path to dataset files:", path)
# Out:
# Path to dataset files: /home/ajh1729/.cache/kagglehub/datasets/tunguz/200000-jeopardy-questions/versions/1

# %%
import pandas as pd
import os

# Import Jeopardy Questions
data = pd.read_csv('/home/ajh1729/.cache/kagglehub/datasets/tunguz/200000-jeopardy-questions/versions/1/JEOPARDY_CSV.csv')
data = pd.DataFrame(data=data)

# Lowercase, strip whitespace, and view column names
data.columns = map(lambda x: x.lower().strip(), data.columns)

# Reduce size of data
data = data[0:1000]

# Tokenize Jeopardy Questions
data["question_tokens"] = data["question"].apply(lambda x: nlp(x))

# %%
# View first question
example_question = data.question[0]
example_question_tokens = data.question_tokens[0]
print("The first questions is:")
print(example_question)
# Out:
# The first questions is:
# For the last 8 years of his life, Galileo was under house arrest for espousing this man's theory

# %%
# Print individual tokens of first question
print("The tokens from the first question are:")
for tokens in example_question_tokens:
    print(tokens)
# Out:
# The tokens from the first question are:
# For
# the
# last
# 8
# years
# of
# his
# life
# ,
# Galileo
# was
# under
# house
# arrest
# for
# espousing
# this
# man
# 's
# theory

# %%
# Print Part-of-speech tags for tokens in the first question
print("Here are the Part-of-speech tags for each token in the first question:")
for token in example_question_tokens:
    print(token.text,token.pos_, spacy.explain(token.pos_))
# Out:
# Here are the Part-of-speech tags for each token in the first question:
# For ADP adposition
# the DET determiner
# last ADJ adjective
# 8 NUM numeral
# years NOUN noun
# of ADP adposition
# his PRON pronoun
# life NOUN noun
# , PUNCT punctuation
# Galileo PROPN proper noun
# was AUX auxiliary
# under ADP adposition
# house NOUN noun
# arrest NOUN noun
# for ADP adposition
# espousing VERB verb
# this DET determiner
# man NOUN noun
# 's PART particle
# theory NOUN noun

# %%
# Print Dependency Parsing tags for tokens in the first question
for token in example_question_tokens:
    print(token.text,token.dep_, spacy.explain(token.dep_))
# Out:
# For prep prepositional modifier
# the det determiner
# last amod adjectival modifier
# 8 nummod numeric modifier
# years pobj object of preposition
# of prep prepositional modifier
# his poss possession modifier
# life pobj object of preposition
# , punct punctuation
# Galileo nsubj nominal subject
# was ROOT None
# under prep prepositional modifier
# house compound compound
# arrest pobj object of preposition
# for prep prepositional modifier
# espousing pcomp complement of preposition
# this det determiner
# man poss possession modifier
# 's case case marking
# theory dobj direct object

# %% [markdown]
# # spaCy, fast.ai, and Hugging face
#  오픈 소스 소프트웨어 라이브러리
#
# 1. spaCy\
#     2015 출시. 2001년 출시된 NLTK(Natural Language Toolkit)이후 대규모 데이터 처리를 염두에 둔 라이브러리\
#     트랜스포머 기반 모델 지원, 데이터 라벨링 및 주석 위한 Prodigy라는 도구 제공
#
# 2. fast.ai\
#     Pytorch 기반 오픈 소스 라이브러리\
#     사용하기 쉽고 학습에 적합하지만 spaCy, Hugging face 보단 덜 성숙?함
#     * mature : 대중 친화적인 라이브러리
#
# 3. Hugging face\
#     NLP 특화 기업\
#     transformer, Pytorch, Tensorflow 기반 라이브러리 지원

# %%
# Visualize the dependency parse
from spacy import displacy

displacy.render(example_question_tokens, style='dep',
                jupyter=True, options={'distance': 120})
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="343e4efbcc8543bfbd6660c9c2f5fc8b-0" class="displacy" width="2330" height="437.0" direction="ltr" style="max-width: none; height: 437.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">For</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="170">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="170">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="290">last</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="290">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="410">8</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="410">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="530">years</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="530">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="650">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="650">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="770">his</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="770">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="890">life,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="890">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="1010">Galileo</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1010">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="1130">was</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1130">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="1250">under</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1250">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="1370">house</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1370">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="1490">arrest</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1490">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="1610">for</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1610">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="1730">espousing</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1730">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="1850">this</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1850">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="1970">man</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1970">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="2090">'s</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2090">PART</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="2210">theory</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2210">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-343e4efbcc8543bfbd6660c9c2f5fc8b-0-0" stroke-width="2px" d="M70,302.0 C70,2.0 1130.0,2.0 1130.0,302.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-343e4efbcc8543bfbd6660c9c2f5fc8b-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">prep</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,304.0 L62,292.0 78,292.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-343e4efbcc8543bfbd6660c9c2f5fc8b-0-1" stroke-width="2px" d="M190,302.0 C190,122.0 520.0,122.0 520.0,302.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-343e4efbcc8543bfbd6660c9c2f5fc8b-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M190,304.0 L182,292.0 198,292.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-343e4efbcc8543bfbd6660c9c2f5fc8b-0-2" stroke-width="2px" d="M310,302.0 C310,182.0 515.0,182.0 515.0,302.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-343e4efbcc8543bfbd6660c9c2f5fc8b-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">amod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M310,304.0 L302,292.0 318,292.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-343e4efbcc8543bfbd6660c9c2f5fc8b-0-3" stroke-width="2px" d="M430,302.0 C430,242.0 510.0,242.0 510.0,302.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-343e4efbcc8543bfbd6660c9c2f5fc8b-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nummod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M430,304.0 L422,292.0 438,292.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-343e4efbcc8543bfbd6660c9c2f5fc8b-0-4" stroke-width="2px" d="M70,302.0 C70,62.0 525.0,62.0 525.0,302.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-343e4efbcc8543bfbd6660c9c2f5fc8b-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">pobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M525.0,304.0 L533.0,292.0 517.0,292.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-343e4efbcc8543b

# %%
# Print tokens for example sentence without chunking
for token in nlp("My parents live in New York City."):
    print(token.text)
# Out:
# My
# parents
# live
# in
# New
# York
# City
# .

# %%
for chunk in nlp("My parents live in New York City.").noun_chunks:
      print(chunk.text)
# Out:
# My parents
# New York City

# %%
# Print lemmatization for tokens in the first question
lemmatization = pd.DataFrame(data=[], \
  columns=["original","lemmatized"])
i = 0
for token in example_question_tokens:
    lemmatization.loc[i,"original"] = token.text
    lemmatization.loc[i,"lemmatized"] = token.lemma_
    i = i+1

lemmatization
# Out:
#      original lemmatized
# 0         For        for
# 1         the        the
# 2        last       last
# 3           8          8
# 4       years       year
# 5          of         of
# 6         his        his
# 7        life       life
# 8           ,          ,
# 9     Galileo    Galileo
# 10        was         be
# 11      under      under
# 12      house      house
# 13     arrest     arrest
# 14        for        for
# 15  espousing    espouse
# 16       this       this
# 17        man        man
# 18         's         's
# 19     theory     theory

# %%
# Print NER results
example_sentence = "George Washington was an American political leader, \
military general, statesman, and Founding Father who served as the \
first president of the United States from 1789 to 1797.\n"

print(example_sentence)

print("Text Start End Label")
doc = nlp(example_sentence)
for token in doc.ents:
    print(token.text, token.start_char, token.end_char, token.label_)
# Out:
# George Washington was an American political leader, military general, statesman, and Founding Father who served as the first president of the United States from 1789 to 1797.
#
# Text Start End Label
# George Washington 0 17 PERSON
# American 25 33 NORP
# first 119 124 ORDINAL
# the United States 138 155 GPE
# from 1789 to 1797 156 173 DATE

# %%
# Visualize NER results
displacy.render(doc, style='ent', jupyter=True, options={'distance': 120})
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     George Washington
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  was an
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     American
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  political leader, military general, statesman, and Founding Father who served as the
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     first
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
#  president of
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the United States
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     from 1789 to 1797
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# .</br></div></span>

# %%
# Import libraries
import requests

# Define Google Knowledge Graph API Result function
def returnGraphResult(query, key, entityType):
    if entityType=="PERSON":
        google = f"https://kgsearch.googleapis.com/v1/entities:search\
         # ?query={query}&key={key}"
        resp = requests.get(google)
        url = resp.json()['itemListElement'][0]['result']\
         ['detailedDescription']['url']
        description = resp.json()['itemListElement'][0]['result']\
         ['detailedDescription']['articleBody']
        return url, description
    else:
        return "no_match", "no_match"

# %%
# Print Wikipedia descriptions and URLs for entities
for token in doc.ents:
    url, description = returnGraphResult(token.text, key, token.label_) # key????????
    print(token.text, token.label_, url, description)
# Out:
# (George Washington, American, first, the United States, from 1789 to 1797)
